# %% [markdown]
# # Imports

# %%
import math
import os
import sys

import boto3
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sys.path.append("scripts")
from deseq.deseq_data import create_deseq_metadata
from expressions_EDA import load_est_counts_from_s3

# %% [markdown]
# # Preparing Sample Metadata for DESeq2 Differential Expression Analysis

# %%
annotations_filtered = pd.read_csv("../data/annotations_whole_blood.csv", index_col=0)

# %%
annotations_filtered.Diagnosis.value_counts()
# Out:
# Healthy                                     292
# Systemic_lupus_erythematosus                196
# Rheumatoid_arthritis                        190
# Juvenile_idiopathic_arthritis               115
# Type_1_diabetes_mellitus                     65
# Crohn_disease                                60
# Relapsing-remitting_multiple_sclerosis       20
# Systemic_inflammatory_response_syndrome      17
# Ulcerative_colitis                           15
# Psoriasis                                    10
# Arthropathic_psoriasis                       10
# Secondary_progressive_multiple_sclerosis     10
# Ankylosing_spondylitis                        8
# Name: Diagnosis, dtype: int64

# %%
annotations_filtered
# Out:
#                Dataset          Run         GSM  Sample_type  \
# SRX3703081   GSE110685   SRR6730133  GSM3011776  Whole_blood
# SRX3703083   GSE110685   SRR6730135  GSM3011778  Whole_blood
# SRX3703084   GSE110685   SRR6730136  GSM3011779  Whole_blood
# SRX3703085   GSE110685   SRR6730137  GSM3011780  Whole_blood
# SRX3703086   GSE110685   SRR6730138  GSM3011781  Whole_blood
# ...                ...          ...         ...          ...
# SRX12109261  GSE183701  SRR15817169  GSM5568065  Whole_blood
# SRX12109262  GSE183701  SRR15817170  GSM5568066  Whole_blood
# SRX12109263  GSE183701  SRR15817171  GSM5568067  Whole_blood
# SRX12109264  GSE183701  SRR15817172  GSM5568068  Whole_blood
# SRX12109265  GSE183701  SRR15817173  GSM5568069  Whole_blood
#
#              Sample_type_details   Tissue_stimulation     Therapy_type  \
# SRX3703081                   NaN  Without_stimulation  Without_therapy
# SRX3703083                   NaN  Without_stimulation  Without_therapy
# SRX3703084                   NaN  Without_stimulation  Without_therapy
# SRX3703085                   NaN  Without_stimulation  Without_therapy
# SRX3703086                   NaN  Without_stimulation  Without_therapy
# ...                          ...                  ...              ...
# SRX12109261                  NaN  Without_stimulation  Without_therapy
# SRX12109262                  NaN  Without_stimulation  Without_therapy
# SRX12109263                  NaN  Without_stimulation          No_data
# SRX12109264                  NaN  Without_stimulation          No_data
# SRX12109265                  NaN  Without_stimulation          No_data
#
#                                 Diagnosis Diagnosis_comment  Stage  ...  \
# SRX3703081                        Healthy               NaN    NaN  ...
# SRX3703083                        Healthy               NaN    NaN  ...
# SRX3703084   Systemic_lupus_erythematosus               NaN    NaN  ...
# SRX3703085   Systemic_lupus_erythematosus               NaN    NaN  ...
# SRX3703086   Systemic_lupus_erythematosus               NaN    NaN  ...
# ...                                   ...               ...    ...  ...
# SRX12109261                       Healthy               NaN    NaN  ...
# SRX12109262                       Healthy               NaN    NaN  ...
# SRX12109263      Type_1_diabetes_mellitus               NaN    NaN  ...
# SRX12109264      Type_1_diabetes_mellitus               NaN    NaN  ...
# SRX12109265      Type_1_diabetes_mellitus               NaN    NaN  ...
#
#              Layout  Readcounts To_check  QC_bad  QC_good  QC_score  \
# SRX3703081   SINGLE   8677272.0      NaN     NaN      NaN       NaN
# SRX3703083   SINGLE   9675604.0      NaN     NaN      NaN       NaN
# SRX3703084   SINGLE  40939864.0      NaN     NaN      NaN       NaN
# SRX3703085   SINGLE   8744154.0      NaN     NaN      NaN       NaN
# SRX3703086   SINGLE  31979792.0      NaN     NaN      NaN       NaN
# ...             ...         ...      ...     ...      ...       ...
# SRX12109261  PAIRED   5287469.0      NaN     NaN      NaN  5.541667
# SRX12109262  PAIRED   4534915.0      NaN     NaN      NaN  5.541667
# SRX12109263  PAIRED   2577781.0      NaN     NaN      NaN  4.958333
# SRX12109264  PAIRED   4653394.0      NaN     NaN      NaN  5.541667
# SRX12109265  PAIRED   4720930.0      NaN     NaN      NaN  5.541667
#
#              Who_checks  Decision  Expression_comment  Spike_in
# SRX3703081          NaN       NaN                 NaN       NaN
# SRX3703083          NaN       NaN                 NaN       NaN
# SRX3703084          NaN       NaN                 NaN       NaN
# SRX3703085          NaN       NaN                 NaN       NaN
# SRX3703086          NaN       NaN                 NaN       NaN
# ...                 ...       ...                 ...       ...
# SRX12109261         NaN       NaN                 NaN       NaN
# SRX12109262         NaN       NaN                 NaN       NaN
# SRX12109263         NaN       NaN                 NaN       NaN
# SRX12109264         NaN       NaN                 NaN       NaN
# SRX12109265         NaN       NaN                 NaN       NaN
#
# [1008 rows x 47 columns]

# %%
files = create_deseq_metadata(annotations_filtered, output_dir="../data/deseq/metadata")
# Out:
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE110685_Systemic_lupus_erythematosus.csv (35 diseased + 16 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE117769_Rheumatoid_arthritis.csv (51 diseased + 49 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE117769_Ankylosing_spondylitis.csv (8 diseased + 49 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE117769_Arthropathic_psoriasis.csv (10 diseased + 49 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE112057_Crohn_disease.csv (60 diseased + 12 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE112057_Ulcerative_colitis.csv (15 diseased + 12 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE112057_Juvenile_idiopathic_arthritis.csv (115 diseased + 12 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE90081_Rheumatoid_arthritis.csv (12 diseased + 12 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE123658_Type_1_diabetes_mellitus.csv (39 diseased + 43 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE72509_Systemic_lupus_erythematosus.csv (99 diseased + 18 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE147339_Psoriasis.csv (10 diseased + 10 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE112087_Systemic_lupus_erythematosus.csv (62 diseased + 58 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE120178_Rheumatoid_arthritis.csv (127 diseased + 13 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE159225_Relapsing-remitting_multiple_sclerosis.csv (20 diseased + 20 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE159225_Secondary_progressive_multiple_sclerosis.csv (10 diseased + 20 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE176260_Systemic_inflammatory_response_syndrome.csv (17 diseased + 15 healthy)
# ✔ Saved: ../data/deseq/metadata/DESeq_metadata_GSE183701_Type_1_diabetes_mellitus.csv (26 diseased + 26 healthy)

# %% [markdown]
# # Importing Raw Gene Expression Counts from Amazon S3

# %%
samples = annotations_filtered.index.tolist()

# %%
expr_counts = load_est_counts_from_s3(samples)
expr_counts.to_csv("../data/expression_counts.csv")
# Out:
# Loaded: database/SRX3703081/kallisto/SRX3703081-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703083/kallisto/SRX3703083-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703084/kallisto/SRX3703084-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703085/kallisto/SRX3703085-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703086/kallisto/SRX3703086-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703087/kallisto/SRX3703087-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703088/kallisto/SRX3703088-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703089/kallisto/SRX3703089-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703090/kallisto/SRX3703090-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703091/kallisto/SRX3703091-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703092/kallisto/SRX3703092-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703093/kallisto/SRX3703093-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703094/kallisto/SRX3703094-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3703095/kallisto/SRX3703095-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX3
kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109237/kallisto/SRX12109237-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109238/kallisto/SRX12109238-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109239/kallisto/SRX12109239-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109240/kallisto/SRX12109240-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109242/kallisto/SRX12109242-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109244/kallisto/SRX12109244-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109246/kallisto/SRX12109246-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109247/kallisto/SRX12109247-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109249/kallisto/SRX12109249-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109250/kallisto/SRX12109250-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109251/kallisto/SRX12109251-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109253/kallisto/SRX12109253-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109254/kallisto/SRX12109254-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109255/kallisto/SRX12109255-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109256/kallisto/SRX12109256-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109258/kallisto/SRX12109258-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109259/kallisto/SRX12109259-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109260/kallisto/SRX12109260-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109261/kallisto/SRX12109261-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109262/kallisto/SRX12109262-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109263/kallisto/SRX12109263-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109264/kallisto/SRX12109264-kallisto-Xena-gene-est_counts_without_noncoding.tsv
# Loaded: database/SRX12109265/kallisto/SRX12109265-kallisto-Xena-gene-est_counts_without_noncoding.tsv
#
# Final expression matrix shape: (20062, 1008)

# %% [markdown]
# # Running DESeq2 and Analyzing Results

# %%
# !python scripts/deseq/run_deseq2_pipeline.py

# %%
results_folder = "../data/deseq/results"
lfc_threshold = 0.58
files = [
    f
    for f in os.listdir(results_folder)
    if f.endswith(".csv") and "_DEGs" not in f and "_TOP" not in f
]

ncols = 3
nrows = math.ceil(len(files) / ncols)

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(5 * ncols, 4 * nrows))
axes = axes.flatten()

for idx, file in enumerate(files):
    ax = axes[idx]
    path = os.path.join(results_folder, file)
    df = pd.read_csv(path)

    if "padj" not in df.columns or "log2FoldChange" not in df.columns:
        continue

    df = df.dropna(subset=["padj", "log2FoldChange"])
    df["neg_log10_padj"] = -np.log10(df["padj"])
    df["significant"] = (df["padj"] < 0.05) & (
        abs(df["log2FoldChange"]) > lfc_threshold
    )

    ax.scatter(
        df["log2FoldChange"],
        df["neg_log10_padj"],
        c=df["significant"].map({True: "red", False: "grey"}),
        alpha=0.6,
        edgecolors="none",
    )

    ax.axhline(-np.log10(0.05), color="blue", linestyle="--", linewidth=1)
    ax.axvline(-lfc_threshold, color="green", linestyle="--", linewidth=1)
    ax.axvline(lfc_threshold, color="green", linestyle="--", linewidth=1)

    ax.set_title(file.replace("deseq2_", "").replace(".csv", ""))
    ax.set_xlabel("log2 Fold Change")
    ax.set_ylabel("-log10(padj)")

for j in range(len(files), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
results_folder = "../data/deseq/results"
all_deg = []

required_columns = ["gene", "log2FoldChange", "padj", "direction"]

for file in os.listdir(results_folder):
    if not file.endswith("_DEGs.csv"):
        continue

    path = os.path.join(results_folder, file)
    df = pd.read_csv(path)

    missing = [col for col in required_columns if col not in df.columns]
    if missing:
        print(f"Пропускаем файл {file} — нет колонок: {missing}")
        continue

    condition = file.replace("deseq2_", "").replace("_DEGs.csv", "")
    diagnosis = condition.split("_", 1)[1]
    df["diagnosis"] = diagnosis

    all_deg.append(df[required_columns + ["diagnosis"]])

if all_deg:
    merged = pd.concat(all_deg, ignore_index=True)
    merged.to_csv(
        os.path.join(results_folder, "ALL_DEGs_combined_all.csv"), index=False
    )
    print("Merged DEGs:", merged.shape)
else:
    print("Files are not found.")
# Out:
# Merged DEGs: (16071, 5)

# %%
up_in_disease = merged[merged["direction"] == "up_in_disease"]
disease_counts = up_in_disease["gene"].value_counts().reset_index()
disease_counts.columns = ["gene", "n_diagnoses_up_in_disease"]

disease_counts.query("n_diagnoses_up_in_disease > 5 ")
# Out:
#            gene  n_diagnoses_up_in_disease
# 0            HP                         11
# 1       ADAMTS2                         11
# 2          ARG1                         11
# 3         DAAM2                         11
# 4       TNFAIP6                         11
# ..          ...                        ...
# 231        OLR1                          6
# 232  CSGALNACT2                          6
# 233       IGHG1                          6
# 234       MCTP1                          6
# 235      MAP2K6                          6
#
# [236 rows x 2 columns]

# %%
top_genes = disease_counts.query("n_diagnoses_up_in_disease > 6")["gene"].tolist()
len(top_genes)
# Out:
# 143

# %%
results_folder = "../data/deseq/results"
merged = pd.read_csv(os.path.join(results_folder, "ALL_DEGs_combined_all.csv"))
merged = merged.dropna(subset=["padj"])
top_genes_per_diagnosis = (
    merged.sort_values(["diagnosis", "padj"])
    .groupby("diagnosis", group_keys=False)
    .head(50)
)

output_path = os.path.join(results_folder, "TOP50_DEGs_per_diagnosis.csv")
top_genes_per_diagnosis.to_csv(output_path, index=False)

print(f"Сохранено: {output_path} ({top_genes_per_diagnosis.shape[0]} строк)")
# Out:
# Сохранено: ../data/deseq/results/TOP50_DEGs_per_diagnosis.csv (575 строк)

# %%
gene_diagnosis_counts = (
    top_genes_per_diagnosis.groupby("gene")["diagnosis"]
    .nunique()
    .reset_index(name="n_diagnoses")
    .sort_values("n_diagnoses", ascending=False)
)

output_path = os.path.join(results_folder, "UNIQUE_genes_from_TOP50_with_counts.csv")
gene_diagnosis_counts.to_csv(output_path, index=False)

print(f"Saved {gene_diagnosis_counts.shape[0]} genes: {output_path}")
# Out:
# Saved 500 genes: ../data/deseq/results/UNIQUE_genes_from_TOP50_with_counts.csv

# %%
top_genes2 = gene_diagnosis_counts.query("n_diagnoses > 1")["gene"].tolist()
len(top_genes2)
# Out:
# 53

# %%
literature_found_list = [
    "HP",
    "ARG1",
    "C1QC",
    "C1QB",
    "METTL7B",
    "S100A12",
    "S100A9",
    "MCEMP1",
    "RNASE1",
    "ANXA3",
    "BMX",
    "CA4",
    "CD177",
    "OLAH",
    "SLC26A8",
    "FOLR3",
    "S100A8",
    "MMP8",
    "ADAMTS2",
    "FCGR1B",
    "ITGA7",
    "SAMSN1",
    "GRB10",
    "DHRS9",
    "ALOX5AP",
    "MPO",
    "TDRD9",
    "NAIP",
    "RETN",
    "BPI",
    "PLBD1",
    "VNN1",
    "GADD45A",
    "RNASE2",
    "ABCA1",
    "IFI27",
    "C1QA",
    "AIM2",
    "GPR84",
    "DEFA3",
    "GALNT14",
    "IL1R2",
    "TNFAIP6",
    "LCN2",
    "CLEC4D",
    "FCAR",
    "PGLYRP1",
    "BATF2",
    "CRISP3",
    "FCER1G",
    "IRAK3",
    "LILRA5",
    "LTF",
    "ASPH",
    "AC007325.1",
    "CNGB1",
    "COL17A1",
    "DUSP13",
    "GPR42",
    "LIPM",
    "LRRN1",
    "MAOA",
    "PLIN4",
    "POM121L7",
]

# %%
final_genes = list(set(literature_found_list) | set(top_genes) | set(top_genes2))
len(final_genes)
# Out:
# 206

# %%
with open("../data/final_dif_gene_list.txt", "w") as f:
    for gene in final_genes:
        f.write(gene + "\n")
